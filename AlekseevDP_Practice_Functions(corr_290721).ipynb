# %%
# Алексеев Д.П. (DSU-4, PYDA-21)
# Домашнее задание к лекции "Функции"

# Вам нужно помочь секретарю автоматизировать работу. Для этого нужно написать программу, которая будет на основе 
# хранимых данных исполнять пользовательские команды.

# Исходные данные имеют следующую структуру:

# 1. перечень всех документов
# documents = [
# {‘type’: ‘passport’, ‘number’: ‘2207 876234’, ‘name’: ‘Василий Гупкин’},
# {‘type’: ‘invoice’, ‘number’: ‘11-2’, ‘name’: ‘Геннадий Покемонов’},
# {‘type’: ‘insurance’, ‘number’: ‘10006’, ‘name’: ‘Аристарх Павлов’}
# ]

# 2.перечень полок, на которых хранятся документы (если документ есть в documents, 
# то он обязательно должен быть и в directories)
# directories = {
# ‘1’: [‘2207 876234’, ‘11-2’],
# ‘2’: [‘10006’],
# ‘3’: []
# }

# Общие требования к программе:
# -код должен быть грамотно декомпозирован (каждая функция отвечает за свою конкретную задачу, 
# дублирующийся функционал переиспользуется, а его код не повторяется);
# -в коде отсутствуют глобальные переменные (за исключением documents и directories);
# -пользовательский ввод обрабатывается в цикле while до тех пор, 
# пока пользователь явно не завершит программу (вводом команды “q”).

# Задание 1
# Пункт 1. Пользователь по команде “p” может узнать владельца документа по его номеру
# Примеры работы:

# Введите команду:
# p
# Введите номер документа:
# 10006
# Результат:
# Владелец документа: Аристарх Павлов

# Введите команду:
# p
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# Пункт 2. Пользователь по команде “s” может по номеру документа узнать на какой полке он хранится
# Примеры работы:

# Введите команду:
# s
# Введите номер документа:
# 10006
# Результат:
# Документ хранится на полке: 2

# Введите команду:
# p
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# Пункт 3. Пользователь по команде “l” может увидеть полную информацию по всем документам
# Пример работы:

# Введите команду:
# l
# Результат:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# Пункт 4. Пользователь по команде “as” может добавить новую полку
# Примеры работы:

# Введите команду:
# as
# Введите номер полки:
# 10
# Результат:
# Полка добавлена. Текущий перечень полок: 1, 2, 3, 10.

# Введите команду:
# as
# Введите номер полки:
# 1
# Результат:
# Такая полка уже существует. Текущий перечень полок: 1, 2, 3.

# Пункт 5. Пользователь по команде “ds” может удалить существующую полку из данных (только если она пустая)
# Примеры работы:

# Введите команду:
# ds
# Введите номер полки:
# 3
# Результат:
# Полка удалена. Текущий перечень полок: 1, 2.

# Введите команду:
# ds
# Введите номер полки:
# 1
# Результат:
# На полке есть документа, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3.

# Введите команду:
# ds
# Введите номер полки:
# 4
# Результат:
# Такой полки не существует. Текущий перечень полок: 1, 2, 3.

# %%
# 1. перечень всех документов
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# 2.перечень полок, на которых хранятся документы (если документ есть в documents, 
# то он обязательно должен быть и в directories)
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

documents
directories
# Out:
# {'1': ['2207 876234', '11-2'], '2': ['10006'], '3': []}

# %%
def func_p():
    success = 0
    print('p (узнать владельца документа по его номеру)')
    input_doc_number = input("Введите номер документа: ")
    for doc in documents:
        if doc['number'] == input_doc_number:
            print("Владелец документа: ", doc['name'])
            success = 1
            break
    if success == 0:
        print("Документ не найден в базе")   
    return

def func_s():
    success = 0
    print('s (по номеру документа узнать, на какой полке он хранится)')
    input_doc_number = input("Введите номер документа: ")
    for key,value in directories.items():
        if input_doc_number in value:
            print("Номер полки: ", key)
            success = 1
            break
    if success == 0:
        print("Документ не найден в базе")
    return
            
def func_l():       
    print('l (просмотр полной информации по всем документам)')
    for doc in documents:
        for key,value in directories.items():    
            if doc['number'] in value:
                break
        print("№:", doc['number'], ", тип:", doc['type'], ", владелец:", doc['name'], ", полка хранения:", key)   
    return

def func_as():    
    print('as (добавление новой полки)')
    input_shelf_number = input("Введите номер добавляемой полки: ")
    if input_shelf_number in directories.keys():
        print("Такая полка уже существует. Текущий перечень полок:", [keylist for keylist in directories.keys()])
        pass
    else:  
        # исправлено на добавление пустой полки вместо первого варианта (добавления полки с уже внесенным документом):
        directories[input_shelf_number] = [] 
        print("Полка добавлена. Текущий перечень полок:", [keylist for keylist in directories.keys()])
    return

def func_ds(): 
    print('ds (удалить существующую полку из данных (только если она пустая))')
    input_shelf_number = input("Введите номер удаляемой полки: ")
    if input_shelf_number in directories.keys():
        if len(directories[input_shelf_number]) > 0:
            print("На полке есть документы, удалите их перед удалением полки. Текущий перечень полок:", 
                [keylist for keylist in directories.keys()])
        else:
            del(directories[input_shelf_number])
            print("Полка удалена. Текущий перечень полок:", [keylist for keylist in directories.keys()])
    else:
        print("Такой полки не существует. Текущий перечень полок:", [keylist for keylist in directories.keys()])
    return

def main():
    while True:
        success = 0
        user_input = input("Введите команду: ")
        
        if user_input.lower() == 'p':
            func_p()
            
        if user_input.lower() == 's':
            func_s()
                
        if user_input.lower() == 'l':
            func_l()
                
        if user_input.lower() == 'as':
            func_as()
                                                  
        if user_input.lower() == 'ds':
            func_ds()

        elif user_input.lower() == 'q':
            print('q (выход из программы)')
            break
            
main()
# Out:
# Введите команду: ds
# ds (удалить существующую полку из данных (только если она пустая))
# Введите номер удаляемой полки: 4
# Полка удалена. Текущий перечень полок: ['1', '2', '3']
# Введите команду: q
# q (выход из программы)

# %%
directories
# Out:
# {'1': ['2207 876234', '11-2'], '2': ['10006'], '3': []}
